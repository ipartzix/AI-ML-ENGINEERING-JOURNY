# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\AI ML ENGINEERING JOURNY\02_Python_Foundations\04_Pandas\data.csv')

# %% [markdown]
# ### Add an r before your opening quote. This tells Python to treat every character in the string literally and ignore escape sequences.
