# %% [markdown]
# # Loading in dataframes from Files

# %%
import pandas as pd

# %%
pd.read_csv(r"D:\AI ML ENGINEERING JOURNY\02_Python_Foundations\04_Pandas\Advance_Pandas\data.csv")
# Out:
#        -ResponseId                      MainBranch                 Age  \
# 0                1  I am a developer by profession  Under 18 years old
# 1                2  I am a developer by profession     35-44 years old
# 2                3  I am a developer by profession     45-54 years old
# 3                4           I am learning to code     18-24 years old
# 4                5  I am a developer by profession     18-24 years old
# ...            ...                             ...                 ...
# 65432        65433  I am a developer by profession     18-24 years old
# 65433        65434  I am a developer by profession     25-34 years old
# 65434        65435  I am a developer by profession     25-34 years old
# 65435        65436  I am a developer by profession     18-24 years old
# 65436        65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
result = pd.read_csv(r"D:\AI ML ENGINEERING JOURNY\02_Python_Foundations\04_Pandas\Advance_Pandas\student_results.csv")

# %%
result.head()
# Out:
#    Student_ID   Name  Marks Branch Result
# 0         101   Amit     78    CSE   Pass
# 1         102   Riya     85    CSE   Pass
# 2         103  Sohan     62    ECE   Pass
# 3         104   Neha     90    CSE   Pass
# 4         105  Karan     55     ME   Fail

# %%
pd.read_csv(
    "https://raw.githubusercontent.com/MainakRepositor/Datasets/master/Deep%20NLP/Sheet_1.csv"
)
# Out:
#     response_id        class  \
# 0    response_1  not_flagged
# 1    response_2      flagged
# 2    response_3      flagged
# 3    response_4  not_flagged
# 4    response_5  not_flagged
# ..          ...          ...
# 75  response_76  not_flagged
# 76  response_77      flagged
# 77  response_78  not_flagged
# 78  response_79      flagged
# 79  response_80  not_flagged
#
#                                         response_text Unnamed: 3  Unnamed: 4  \
# 0               I try and avoid this sort of conflict        NaN         NaN
# 1   Had a friend open up to me about his mental ad...        NaN         NaN
# 2   I saved a girl from suicide once. She was goin...        NaN         NaN
# 3   i cant think of one really...i think i may hav...        NaN         NaN
# 4   Only really one friend who doesn't fit into th...                    NaN
# ..                                                ...        ...         ...
# ...

# %%
url = "https://github.com/KeithGalli/complete-pandas-tutorial/raw/master/data/olympics-data.xlsx"
olympics_data = pd.read_excel(url, sheet_name="results")

print(olympics_data.head())
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
pd.read_excel("https://github.com/KeithGalli/complete-pandas-tutorial/raw/master/data/olympics-data.xlsx")
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
olympics_data.tail()
# Out:
#           year    type              discipline                          event  \
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                           as  athlete_id  noc    team  place   tied medal
# 308403         Marián Skupek      148983  SVK     NaN   26.0  False   NaN
# 308404         Elsa Fermbäck      148984  SWE     NaN   28.0  False   NaN
# 308405         Hilma Lövblom      148985  SWE  Sweden   13.0  False   NaN
# 308406         Hilma Lövblom      148985  SWE     NaN    NaN  False   NaN
# 308407  Charlotta Säfvenberg      148986  NaN     NaN   24.0  False   NaN
