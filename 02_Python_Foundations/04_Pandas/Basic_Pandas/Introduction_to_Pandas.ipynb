# %%
import pandas as pd

df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=["A", "B", "C"], index=["X", "Y", "Z"])

# %% [markdown]
# ###  df is represent the data frame .

# %%
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.index.tolist()
# Out:
# ['X', 'Y', 'Z']
