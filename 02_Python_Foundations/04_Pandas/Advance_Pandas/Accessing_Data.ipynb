# %% [markdown]
# # Accessing data with Pandas

# %%
import pandas as pd

# %% [markdown]
# ### It will for basic python code style

# %%
result = pd.read_csv(r"D:\AI ML ENGINEERING JOURNY\02_Python_Foundations\04_Pandas\Advance_Pandas\student_results.csv")

# %%
print(result)
# Out:
#    Student_ID   Name  Marks Branch Result
# 0         101   Amit     78    CSE   Pass
# 1         102   Riya     85    CSE   Pass
# 2         103  Sohan     62    ECE   Pass
# 3         104   Neha     90    CSE   Pass
# 4         105  Karan     55     ME   Fail

# %%
result.head()
# Out:
#    Student_ID   Name  Marks Branch Result
# 0         101   Amit     78    CSE   Pass
# 1         102   Riya     85    CSE   Pass
# 2         103  Sohan     62    ECE   Pass
# 3         104   Neha     90    CSE   Pass
# 4         105  Karan     55     ME   Fail

# %%
result.head(2)
# Out:
#    Student_ID  Name  Marks Branch Result
# 0         101  Amit     78    CSE   Pass
# 1         102  Riya     85    CSE   Pass

# %%
result.tail(2)
# Out:
#    Student_ID   Name  Marks Branch Result
# 3         104   Neha     90    CSE   Pass
# 4         105  Karan     55     ME   Fail

# %%
result.loc[4]
# Out:
# Student_ID      105
# Name          Karan
# Marks            55
# Branch           ME
# Result         Fail
# Name: 4, dtype: object

# %%
result.loc[[1, 3, 4]]
# Out:
#    Student_ID   Name  Marks Branch Result
# 1         102   Riya     85    CSE   Pass
# 3         104   Neha     90    CSE   Pass
# 4         105  Karan     55     ME   Fail

# %%
result.loc[2:4]
# Out:
#    Student_ID   Name  Marks Branch Result
# 2         103  Sohan     62    ECE   Pass
# 3         104   Neha     90    CSE   Pass
# 4         105  Karan     55     ME   Fail

# %%
result.loc[2:4, "Name"]
# Out:
# 2    Sohan
# 3     Neha
# 4    Karan
# Name: Name, dtype: str

# %%
result.index = result["Marks"]

# %%
result.head()
# Out:
#        Student_ID   Name  Marks Branch Result
# Marks
# 78            101   Amit     78    CSE   Pass
# 85            102   Riya     85    CSE   Pass
# 62            103  Sohan     62    ECE   Pass
# 90            104   Neha     90    CSE   Pass
# 55            105  Karan     55     ME   Fail

# %%
result.loc[1, "Marks"] = 80

# %%
result.head()
# Out:
#        Student_ID   Name  Marks Branch Result
# Marks
# 78          101.0   Amit   78.0    CSE   Pass
# 85          102.0   Riya   85.0    CSE   Pass
# 62          103.0  Sohan   62.0    ECE   Pass
# 90          104.0   Neha   90.0    CSE   Pass
# 55          105.0  Karan   55.0     ME   Fail

# %% [markdown]
# ###  for  accessing single value

# %%
result.at[1, "Name"]  # if index label is 1
# Out:
# nan

# %% [markdown]
# # 🧠 Golden rule (memorize this)
#
# | Accessor | Rows | Columns | Slice? | Labels? |
# | -------- | ---- | ------- | ------ | ------- |
# | `.at`    | 1    | 1       | ❌      | ✅       |
# | `.iat`   | 1    | 1       | ❌      | ❌       |
# | `.loc`   | many | many    | ✅      | ✅       |
# | `.iloc`  | many | many    | ✅      | ❌       |

# %%
result.Name
# Out:
# Marks
# 78     Amit
# 85     Riya
# 62    Sohan
# 90     Neha
# 55    Karan
# 1       NaN
# Name: Name, dtype: str

# %%
result["Name"]
# Out:
# Marks
# 78     Amit
# 85     Riya
# 62    Sohan
# 90     Neha
# 55    Karan
# 1       NaN
# Name: Name, dtype: str

# %%
result.sort_values("Student_ID")
# Out:
#        Student_ID   Name  Marks Branch Result
# Marks
# 78          101.0   Amit   78.0    CSE   Pass
# 85          102.0   Riya   85.0    CSE   Pass
# 62          103.0  Sohan   62.0    ECE   Pass
# 90          104.0   Neha   90.0    CSE   Pass
# 55          105.0  Karan   55.0     ME   Fail
# 1             NaN    NaN   80.0    NaN    NaN
